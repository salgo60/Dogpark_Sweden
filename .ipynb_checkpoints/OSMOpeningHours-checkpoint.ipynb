# %% [markdown]
# ### Opening hours example

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import requests
import time
import pandas as pd

# --- 1️⃣ SPARQL: hämta Wikidata-objekt kopplade till SAT ---
query = """
SELECT ?item ?itemLabel ?coord ?osmRel ?osmWay ?osmNode WHERE {
  # ?item wdt:P6104 wd:Q134294510;
        wdt:P625 ?coord.
  OPTIONAL { ?item wdt:P402 ?osmRel. }      # OSM relation
  OPTIONAL { ?item wdt:P11693 ?osmNode. }   # OSM node
  OPTIONAL { ?item wdt:P10689 ?osmWay. }    # OSM way
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],sv,en". }
}
"""

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

items = []
for r in results["results"]["bindings"]:
    qid = r["item"]["value"].split("/")[-1]
    label = r.get("itemLabel", {}).get("value", "")
    osm_node = r.get("osmNode", {}).get("value", "")
    osm_way = r.get("osmWay", {}).get("value", "")
    osm_rel = r.get("osmRel", {}).get("value", "")
    items.append({
        "qid": qid,
        "label": label,
        "osm_node": osm_node,
        "osm_way": osm_way,
        "osm_rel": osm_rel
    })

print(f"Hittade {len(items)} Wikidata-objekt kopplade till SAT.")


# --- 2️⃣ Funktion för att hämta OSM-taggar via Overpass ---
def get_osm_tags(osm_type, osm_id):
    query = f"""
    [out:json][timeout:25];
    {osm_type}({osm_id});
    out tags;
    """
    url = "https://overpass-api.de/api/interpreter"
    r = requests.get(url, params={"data": query})
    if r.status_code != 200:
        return {}
    data = r.json()
    if not data.get("elements"):
        return {}
    return data["elements"][0].get("tags", {})


# --- 3️⃣ Hämta opening_hours, description m.m. för varje OSM-objekt ---
records = []
for item in items:
    for osm_type, osm_id in [
        ("node", item["osm_node"]),
        ("way", item["osm_way"]),
        ("relation", item["osm_rel"])
    ]:
        if not osm_id:
            continue

        tags = get_osm_tags(osm_type, osm_id)
        if not tags:
            continue

        relevant = {k: v for k, v in tags.items()
                    if k in ["opening_hours", "opening_hours:note", "description", "source:opening_hours", "website"]}

        if relevant:
            record = {
                "qid": item["qid"],
                "label": item["label"],
                "osm_type": osm_type,
                "osm_id": osm_id,
                **relevant
            }
            records.append(record)
            print(f"✅ {item['label']} ({osm_type} {osm_id}) → {list(relevant.keys())}")
        time.sleep(1)  # vänlig paus mot Overpass

# --- 4️⃣ Sammanställ som tabell ---
df = pd.DataFrame(records)
print("\n--- Resultat ---")
print(df)

# --- 5️⃣ Spara till CSV (valfritt) ---
df.to_csv("SAT_opening_hours_OSM.csv", index=False, encoding="utf-8-sig")
print("\n💾 Sparat till SAT_opening_hours_OSM.csv")
# Out:
# Hittade 671 Wikidata-objekt kopplade till SAT.
# ✅ Knicksand enkel grillplats (node 12722789033) → ['description', 'website']
# ✅ Knicksand grillplats (node 12722761765) → ['description', 'website']
# ✅ Knicksand grillplats (node 12722789034) → ['description', 'website']
# ✅ Myrudden, grillplats (node 12873021137) → ['website']
# ✅ Lidö Österhamn grillplats (node 12755413219) → ['website']
# ✅ Roddbåtar att korsa mellan Ingmarsö till Finnhamn (way 39504808) → ['opening_hours']
# ✅ Kompassros (node 476813520) → ['opening_hours']
# ✅ Thielska villan, Fjärdlång (way 222182589) → ['description']
# ✅ Fjärdlång tältplats (node 2550378999) → ['description', 'website']
# ✅ Thielska villan, grillplats, Fjärdlång (node 12771043917) → ['website']
# ✅ Fjärdlång tältplats, grillplats (node 12769968654) → ['website']
# ✅ Pojkarnas udde grillplats (node 12772629157) → ['website']
# ✅ Lanthandel på Finnhamn (node 268910308) → ['opening_hours', 'website']
# ✅ Arholma handel (node 1611299267) → ['opening_hours', 'website']
# ✅ Östemar grillplats nya (node 12748135194) → ['website']
# ✅ Nåttarö tältplats (relation 11478821) → ['website']
# ✅ Saltboden, Landsort (node 9731151623) → ['opening_hours', 'source:opening_hours', 'website']
# ✅ Grinda Lanthandel och Cafe (way 247542038) → ['opening_hours', 'source:opening_hours', 'website']
# ✅ Runmarö lanthandel (way 495386320) → ['opening_hours', 'website']
# ✅ Utö livs (way 229110286) → ['opening_hours', 'source:opening_hours', 'website']
# ✅ Arholma tältplats (node 2960935621) → ['website']
# ✅ Utö tältplats (way 496349657) → ['opening_hours', 'website']
# ✅ Grinda tältplats (way 72716859) → ['website']
# ✅ Yxlö brygga grillplats (node 12814390356) → ['website']
# ✅ Utö gula villan (way 322949084) → ['website']
# ✅ Nya Dannekrogen (way 229110262) → ['website']
# ✅ Aktiv Skärgård Utö (way 229605231) → ['opening_hours', 'website']
# ✅ Rånö tältplats (node 5798509129) → ['website']
# ✅ Finnhamns Krog (node 268910309) → ['opening_hours', 'source:opening_hours', 'website']
# ✅ Finnhamns norra tältplats (way 1416109141) → ['description', 'website']
# ✅ Finnhamn södra tältplats (way 1416109773) → ['description', 'website']
# ✅ Grillplats, Storsand Ålö (node 1412263113) → ['website']

# %%
items
# Out:
# [{'qid': 'Q115303256',
#   'label': 'Ornö kyrkogård',
#   'osm_rel': '',
#   'osm_way': '220390585'},
#  {'qid': 'Q115303257',
#   'label': 'Utö kyrkogård',
#   'osm_rel': '',
#   'osm_way': '237190145'},
#  {'qid': 'Q115305305',
#   'label': 'Sandhamns kyrkogård',
#   'osm_rel': '',
#   'osm_way': '701376877'},
#  {'qid': 'Q116730327',
#   'label': 'Båtluffarleden',
#   'osm_rel': '8603180',
#   'osm_way': ''},
#  {'qid': 'Q121352030',
#   'label': 'Grillplats, Storsand Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121361352',
#   'label': 'Grillplats Grinda södra bryggan',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121361588',
#   'label': 'Källvikens badstrand',
#   'osm_rel': '',
#   'osm_way': '1108943075'},
#  {'qid': 'Q121409629',
#   'label': 'Grillplats Ålö Storsand 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121409637',
#   'label': 'Grillplats Ålö storsand 3',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121409712',
#   'label': 'SAT grill Storsand',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121412621',
#   'label': 'Grillplats Storsand',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121433209',
#   'label': 'Grillplats vid badstrand, Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121433242',
#   'label': 'Grillplats Grinda tältplats syd västra 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121433258',
#   'label': 'Östra grillplatsen vid tältplatsen 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121433272',
#   'label': 'Östra grillplatsen vid tältplatsen 1',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121714588',
#   'label': 'Grinda Klubbudden grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121715058',
#   'label': 'Rast- och grillplats Öja-Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121754355',
#   'label': 'Kålgårdsöns naturreservat, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q121887829',
#   'label': 'Finnhamn badplats',
#   'osm_rel': '',
#   'osm_way': '1305399449'},
#  {'qid': 'Q122018561',
#   'label': 'Sandtagets utegym Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q130338597',
#   'label': 'Norra sand, Utö, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q130338761',
#   'label': 'Norra sand, Utö, grillplats 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q130338821',
#   'label': 'Barnens bad',
#   'osm_rel': '',
#   'osm_way': '1317165259'},
#  {'qid': 'Q131318799',
#   'label': 'Stockholm Archipelago Trail',
#   'osm_rel': '19012437',
#   'osm_way': ''},
#  {'qid': 'Q133366565',
#   'label': 'Arholma minneslund',
#   'osm_rel': '',
#   'osm_way': '513323289'},
#  {'qid': 'Q133374147',
#   'label': 'SAT Arholma',
#   'osm_rel': '19012436',
#   'osm_way': ''},
#  {'qid': 'Q133374185',
#   'label': 'SAT Lidö',
#   'osm_rel': '19020231',
#   'osm_way': ''},
#  {'qid': 'Q133449160',
#   'label': 'SAT Landsort',
#   'osm_rel': '19013576',
#   'osm_way': ''},
#  {'qid': 'Q133453469',
#   'label': 'Grillplats Arholma Nord',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133459438',
#   'label': 'Labyrint, Öja-Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133459454',
#   'label': 'Albert Holms minnessten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133459632',
#   'label': 'Helveteskällan, Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133502246',
#   'label': 'SAT Grinda',
#   'osm_rel': '19079703',
#   'osm_way': ''},
#  {'qid': 'Q133502889',
#   'label': 'Grinda Wärdshus',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133554956',
#   'label': 'SAT Nämdö',
#   'osm_rel': '19013473',
#   'osm_way': ''},
#  {'qid': 'Q133567320',
#   'label': 'Vita stigen, Nämdö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133724230',
#   'label': 'SAT Nåttarö',
#   'osm_rel': '19014571',
#   'osm_way': ''},
#  {'qid': 'Q133724231',
#   'label': 'SAT Rånö',
#   'osm_rel': '19015969',
#   'osm_way': ''},
#  {'qid': 'Q133724232',
#   'label': 'SAT Ålö',
#   'osm_rel': '19012684',
#   'osm_way': ''},
#  {'qid': 'Q133724234',
#   'label': 'SAT Utö',
#   'osm_rel': '19012654',
#   'osm_way': ''},
#  {'qid': 'Q133724236',
#   'label': 'SAT Ornö',
#   'osm_rel': '19023687',
#   'osm_way': ''},
#  {'qid': 'Q133724237',
#   'label': 'SAT Fjärdlång',
#   'osm_rel': '19016280',
#   'osm_way': ''},
#  {'qid': 'Q133724239',
#   'label': 'SAT Svartsö',
#   'osm_rel': '19014515',
#   'osm_way': ''},
#  {'qid': 'Q133724240',
#   'label': 'SAT Brottö',
#   'osm_rel': '19141225',
#   'osm_way': ''},
#  {'qid': 'Q133724246',
#   'label': 'SAT Runmarö',
#   'osm_rel': '19013472',
#   'osm_way': ''},
#  {'qid': 'Q133724247',
#   'label': 'SAT Ingmarsö',
#   'osm_rel': '19080874',
#   'osm_way': ''},
#  {'qid': 'Q133724249',
#   'label': 'SAT Finnhamn',
#   'osm_rel': '19018272',
#   'osm_way': ''},
#  {'qid': 'Q133724250',
#   'label': 'SAT Yxlan',
#   'osm_rel': '19020310',
#   'osm_way': ''},
#  {'qid': 'Q133724252',
#   'label': 'SAT Möja',
#   'osm_rel': '19023630',
#   'osm_way': ''},
#  {'qid': 'Q133724254',
#   'label': 'SAT Furusund',
#   'osm_rel': '19016187',
#   'osm_way': ''},
#  {'qid': 'Q133724255',
#   'label': 'SAT Sandhamn',
#   'osm_rel': '19081125',
#   'osm_way': ''},
#  {'qid': 'Q133794691',
#   'label': 'Norra skogens naturreservat',
#   'osm_rel': '',
#   'osm_way': '1331536835'},
#  {'qid': 'Q133800514',
#   'label': 'Runmarö kyrkogård',
#   'osm_rel': '',
#   'osm_way': '241040773'},
#  {'qid': 'Q133802175',
#   'label': 'Runmarö Hembygdsgård',
#   'osm_rel': '',
#   'osm_way': '224352869'},
#  {'qid': 'Q133812457',
#   'label': 'Roland Svensson Museet',
#   'osm_rel': '',
#   'osm_way': '1305287603'},
#  {'qid': 'Q133812552',
#   'label': 'STF Möja vandrarhem',
#   'osm_rel': '',
#   'osm_way': '226043396'},
#  {'qid': 'Q133812569', 'label': 'Möja Värdshus', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133812682',
#   'label': 'Jeppes Gästgiveri',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133825090',
#   'label': 'Utö Värdshus vandrarhem',
#   'osm_rel': '',
#   'osm_way': '229110248'},
#  {'qid': 'Q133825195',
#   'label': 'Rävstavik badplats',
#   'osm_rel': '',
#   'osm_way': '715392360'},
#  {'qid': 'Q133827327', 'label': 'Nämdö bageri', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133829368', 'label': 'Bistro Sågen', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133829728',
#   'label': 'grillplats Sydfladen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133829736',
#   'label': 'STF Finnhamn vandrarhem',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133829773',
#   'label': 'Finnhamn Lammuddens vindskydd',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133830137',
#   'label': 'Lammuddens grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133830267',
#   'label': 'Vindskydd Talludden',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133830659',
#   'label': 'Grillplats Talludden',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133830825',
#   'label': 'Ragnars kiosk, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133830844',
#   'label': 'Vandrarhemmet, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133834915',
#   'label': 'Grillplats, Storsand Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133838591',
#   'label': 'Utö gästhamn, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133839813',
#   'label': 'Södra fladen Utö, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133839829',
#   'label': 'Södra fladen Utö, vindskydd',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133840505',
#   'label': 'Utö Värdshus',
#   'osm_rel': '',
#   'osm_way': '229110282'},
#  {'qid': 'Q133840505',
#   'label': 'Utö Värdshus',
#   'osm_rel': '',
#   'osm_way': '229110282'},
#  {'qid': 'Q133840685',
#   'label': 'Utö camping grillplats 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133840790',
#   'label': 'Utö camping grillplats 1',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133841438',
#   'label': 'Utö camping grillplats 3',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133841778',
#   'label': 'Utö camping grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133847886',
#   'label': 'Telegrafbergets torn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133848057',
#   'label': 'Telegrafberget',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133848174',
#   'label': 'Vindskydd Ornö museum',
#   'osm_rel': '',
#   'osm_way': '1376426246'},
#  {'qid': 'Q133848185',
#   'label': 'grillplats, Ornö museum',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133848344',
#   'label': 'Rosirska gravkoret',
#   'osm_rel': '',
#   'osm_way': '1376435118'},
#  {'qid': 'Q133848857',
#   'label': 'Västanviks grillplats, Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133849105',
#   'label': 'Lervassastigen',
#   'osm_rel': '11817644',
#   'osm_way': ''},
#  {'qid': 'Q133850783',
#   'label': 'Skärgårdsmuseet Nämdö',
#   'osm_rel': '',
#   'osm_way': '832213123'},
#  {'qid': 'Q133863310',
#   'label': 'Astrid Lindgrens sommarhus Stenhällan',
#   'osm_rel': '',
#   'osm_way': '388325250'},
#  {'qid': 'Q133863316',
#   'label': 'Furusund grillplats Fotbollsplan',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133863446',
#   'label': 'Skomakarens stuga',
#   'osm_rel': '',
#   'osm_way': '388325219'},
#  {'qid': 'Q133863462',
#   'label': 'Villa Romanov',
#   'osm_rel': '',
#   'osm_way': '388325263'},
#  {'qid': 'Q133863715',
#   'label': 'Skärlkarlshamn strand',
#   'osm_rel': '',
#   'osm_way': '1377169457'},
#  {'qid': 'Q133864055',
#   'label': 'Förängsbadet',
#   'osm_rel': '',
#   'osm_way': '1377185410'},
#  {'qid': 'Q133864087',
#   'label': 'Långviks badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864132',
#   'label': 'Saltviks badplats',
#   'osm_rel': '',
#   'osm_way': '620328417'},
#  {'qid': 'Q133864303',
#   'label': 'Hästholmsvikens badplats',
#   'osm_rel': '',
#   'osm_way': 'http://www.wikidata.org/.well-known/genid/1e47bc5f8970b8f44f25c58d6e7309fd'},
#  {'qid': 'Q133864497',
#   'label': 'södra stranden, Sandhamn',
#   'osm_rel': '',
#   'osm_way': 'http://www.wikidata.org/.well-known/genid/2e71967b50c66ea2dcea4c097c0f47b9'},
#  {'qid': 'Q133864540',
#   'label': 'Harviken, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864593',
#   'label': 'Harvikens badstrand',
#   'osm_rel': '',
#   'osm_way': '512145741'},
#  {'qid': 'Q133864622',
#   'label': 'Knicksand enkel grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864761',
#   'label': 'Knicksand grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864801',
#   'label': 'Knicksand grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864847',
#   'label': 'Sandön, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133864944',
#   'label': 'Myrudden, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133867299', 'label': 'Lidö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133867370',
#   'label': 'Furusunds museipaviljong',
#   'osm_rel': '',
#   'osm_way': '388325411'},
#  {'qid': 'Q133872120',
#   'label': 'Lidö Österhamn grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133880548',
#   'label': 'Femsundvikens badplats',
#   'osm_rel': '',
#   'osm_way': '620363898'},
#  {'qid': 'Q133883699',
#   'label': 'Ingmarsö Brottö Hembygdsmuseum',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133884437',
#   'label': 'Isola Bella',
#   'osm_rel': '',
#   'osm_way': '388325321'},
#  {'qid': 'Q133884655',
#   'label': 'Roddbåtar att korsa mellan Ingmarsö till Finnhamn',
#   'osm_rel': '',
#   'osm_way': '39504808'},
#  {'qid': 'Q133884690',
#   'label': 'Norra Ingmarsö brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133884712',
#   'label': 'Åsättra brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133884785',
#   'label': 'Spränga brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133884836', 'label': 'Gruvbryggan', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133884947',
#   'label': 'Brottö kulturreservat',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133885312', 'label': 'Kompassros', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q133885585',
#   'label': 'Arholma brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133885677',
#   'label': 'Simpnäs brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133885997',
#   'label': 'badplats på norra Grinda',
#   'osm_rel': '14757964',
#   'osm_way': ''},
#  {'qid': 'Q133886133',
#   'label': 'Nåttarö badplats',
#   'osm_rel': '',
#   'osm_way': '1089639080'},
#  {'qid': 'Q133886292',
#   'label': 'Nåttarö brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133886565',
#   'label': 'Själudden, tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133895106',
#   'label': 'Vindskydd lilla Jolpan',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133980758',
#   'label': 'Thielska villan, Fjärdlång',
#   'osm_rel': '',
#   'osm_way': '222182589'},
#  {'qid': 'Q133993440',
#   'label': 'Fjärdlång bryggan, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133993942',
#   'label': 'Fjärdlång tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133993978',
#   'label': 'Fjärdlång brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133994022',
#   'label': 'Ragnars kiosk badplats',
#   'osm_rel': '',
#   'osm_way': '506814567'},
#  {'qid': 'Q133994161',
#   'label': 'Styrsvik brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q133994206',
#   'label': 'Skälviks brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134000657',
#   'label': 'Söderboudd brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134005778',
#   'label': 'Thielska villan, grillplats, Fjärdlång',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134005834', 'label': 'Tysta Klint', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134006267',
#   'label': 'Fjärdlång tältplats, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134006727',
#   'label': 'Pojkarnas udde grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134006996',
#   'label': 'Lanthandel på Finnhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007206',
#   'label': 'Södra Ingmarsö brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007303',
#   'label': 'Landsort västra hamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007357',
#   'label': 'Landsort östra hamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007558',
#   'label': 'Sand brygga, Nämdö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007589',
#   'label': 'Nämdöböte brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007653', 'label': 'Solvik brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134007692',
#   'label': 'Östanvik brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134007891',
#   'label': 'Arholma handel',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134008052', 'label': 'Brottö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134008562', 'label': 'Rånö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134078770',
#   'label': 'Nåttarö snorklingsled',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134082069',
#   'label': 'Vänsviken, Nåttarö BBQ',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134082140',
#   'label': 'Östemar grillplats gamla',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134082735',
#   'label': 'Östemar grillplats nya',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134083897',
#   'label': 'Nåttarö tältplats',
#   'osm_rel': '11478821',
#   'osm_way': ''},
#  {'qid': 'Q134176668',
#   'label': 'Kvarnvikens badstrand',
#   'osm_rel': '',
#   'osm_way': '834655198'},
#  {'qid': 'Q134176709',
#   'label': 'Skarsand, Nåttarö',
#   'osm_rel': '',
#   'osm_way': '322935628'},
#  {'qid': 'Q134290283',
#   'label': 'Furusundsbadplats, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134290334',
#   'label': 'Furusundsbadplats',
#   'osm_rel': '',
#   'osm_way': '1376954741'},
#  {'qid': 'Q134297092', 'label': 'Gatan, brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134306927',
#   'label': 'Saltboden, Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134307047',
#   'label': 'Landsort norra hamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134310117',
#   'label': 'Grinda Lanthandel och Cafe',
#   'osm_rel': '',
#   'osm_way': '247542038'},
#  {'qid': 'Q134310449',
#   'label': 'Södra Grinda brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134311495',
#   'label': 'Nåttarö handelsbod',
#   'osm_rel': '',
#   'osm_way': '186188140'},
#  {'qid': 'Q134311548',
#   'label': 'Livsmedelbutiken på Nämdö Solvik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134311974',
#   'label': 'Runmarö lanthandel',
#   'osm_rel': '',
#   'osm_way': '495386320'},
#  {'qid': 'Q134312278',
#   'label': 'Utö livs',
#   'osm_rel': '',
#   'osm_way': '229110286'},
#  {'qid': 'Q134366690',
#   'label': 'Lidö tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134366761',
#   'label': 'Arholma tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134366886',
#   'label': 'Utö tältplats',
#   'osm_rel': '',
#   'osm_way': '496349657'},
#  {'qid': 'Q134367350',
#   'label': 'Norra Svartsö brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134369418',
#   'label': 'Grinda tältplats',
#   'osm_rel': '',
#   'osm_way': '72716859'},
#  {'qid': 'Q134369594',
#   'label': 'Långviks brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134369828',
#   'label': 'Nämdö tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134369914',
#   'label': 'Köpmanholm brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134370050',
#   'label': 'Sandhamn brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134373707',
#   'label': 'Yxlö brygga grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134380404',
#   'label': 'Hamnvikens badplats',
#   'osm_rel': '',
#   'osm_way': '615512178'},
#  {'qid': 'Q134442339',
#   'label': 'Utö gula villan',
#   'osm_rel': '',
#   'osm_way': '322949084'},
#  {'qid': 'Q134442663', 'label': 'Norrö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134442879',
#   'label': 'Norra Grinda brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134443760',
#   'label': 'Källarstugan, Arholma',
#   'osm_rel': '',
#   'osm_way': '465662338'},
#  {'qid': 'Q134444030',
#   'label': 'Österhamns pensionat',
#   'osm_rel': '',
#   'osm_way': '471440188'},
#  {'qid': 'Q134444768',
#   'label': 'Finnhamn brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134444827',
#   'label': 'Nya Dannekrogen',
#   'osm_rel': '',
#   'osm_way': '229110262'},
#  {'qid': 'Q134445091',
#   'label': 'Aktiv Skärgård Utö',
#   'osm_rel': '',
#   'osm_way': '229605231'},
#  {'qid': 'Q134451025',
#   'label': 'Möja Coop',
#   'osm_rel': '',
#   'osm_way': '226042860'},
#  {'qid': 'Q134452061',
#   'label': 'Rånö tältplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134452244',
#   'label': 'Idholmens gårdsbutik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134452251',
#   'label': 'Idholmens badplats',
#   'osm_rel': '',
#   'osm_way': '696324903'},
#  {'qid': 'Q134461524',
#   'label': 'Idholmens grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134461930',
#   'label': 'Finnhamns Krog',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134462751',
#   'label': 'Finnhamns norra tältplats',
#   'osm_rel': '',
#   'osm_way': '1416109141'},
#  {'qid': 'Q134463083',
#   'label': 'Finnhamn södra tältplats',
#   'osm_rel': '',
#   'osm_way': '1416109773'},
#  {'qid': 'Q134465290',
#   'label': 'Tempo, Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134473761',
#   'label': 'Sandhamns värdshus',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134510130',
#   'label': 'Landsort vandrarhemmet',
#   'osm_rel': '',
#   'osm_way': '1178578023'},
#  {'qid': 'Q134513852',
#   'label': 'Landsorts lotsutkik',
#   'osm_rel': '',
#   'osm_way': '701532536'},
#  {'qid': 'Q134513890',
#   'label': 'Sandhamn gamla skola',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134519154',
#   'label': 'Östemar badstrand',
#   'osm_rel': '',
#   'osm_way': '322935632'},
#  {'qid': 'Q134519179',
#   'label': 'Nåttarö vandrarhem',
#   'osm_rel': '',
#   'osm_way': '322935681'},
#  {'qid': 'Q134519257',
#   'label': 'Nåttarö vandrarhem grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134521444',
#   'label': 'Möjaström brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134522797', 'label': 'Bergs brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134522835',
#   'label': 'Ramsmora brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134523091',
#   'label': 'Långviks brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134523792',
#   'label': 'Hotell Furusund',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134523870', 'label': 'Monte Bello', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134523881',
#   'label': 'Optiska telegrafen i Furusund',
#   'osm_rel': '',
#   'osm_way': '388325198'},
#  {'qid': 'Q134523918',
#   'label': 'Duvkällan, Furusund',
#   'osm_rel': '',
#   'osm_way': '1416789353'},
#  {'qid': 'Q134526525',
#   'label': 'kungaristningen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134527130',
#   'label': 'Furusunds brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134527143', 'label': 'Yxlö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134527248',
#   'label': 'Köpmanholms Lanthandel och Grill',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134529043',
#   'label': 'Ornö Brödbod Deli',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134529162', 'label': 'Ornö macken', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134529240',
#   'label': 'Svartsö lanthandel',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134529646', 'label': 'Rånö livs', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134529993',
#   'label': 'Coop Ingmarsö',
#   'osm_rel': '',
#   'osm_way': '620363915'},
#  {'qid': 'Q134531012', 'label': 'Ingmarsö krog', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134537879',
#   'label': 'Vänsvik udd, Nåttarö grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134537980',
#   'label': 'Vänsviken, Nåttarö',
#   'osm_rel': '',
#   'osm_way': '322935629'},
#  {'qid': 'Q134539208',
#   'label': 'Kayakomat Stockholms Skärgård Ornö',
#   'osm_rel': '',
#   'osm_way': '1385588405'},
#  {'qid': 'Q134539845',
#   'label': 'Ornö kyrka brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134561120',
#   'label': 'Lidö kvarn',
#   'osm_rel': '',
#   'osm_way': '292969768'},
#  {'qid': 'Q134561810',
#   'label': 'Arholma Nord Kajak',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134568948',
#   'label': 'Landsorts gästhamn, hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134570185',
#   'label': 'Norr Storsand grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134570492',
#   'label': 'Nåttarö västra campingen grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134571436',
#   'label': 'Svartsö skärgårdshotell och vandrarhem',
#   'osm_rel': '15033302',
#   'osm_way': ''},
#  {'qid': 'Q134572369',
#   'label': 'Svedtiljas Lotstornet',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134572952',
#   'label': 'Sandhamns seglarhotell',
#   'osm_rel': '',
#   'osm_way': '301302737'},
#  {'qid': 'Q134578274',
#   'label': 'Storsand grillplats 1',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134578337',
#   'label': 'Grillplats Storsand',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134579695',
#   'label': 'Storsand Nåttarö grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134579808',
#   'label': 'Storsand grillplats 2 Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134580000',
#   'label': 'SAT grill södra Storsand Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134580057',
#   'label': 'Fyrhistorisk utställning, Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134580561', 'label': 'Möja Outdoor', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134580641', 'label': 'Ragnars kiosk', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134580717',
#   'label': 'Solberga gård Runmarö kajak uthyrning',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134580862',
#   'label': 'Nåttarö kajakuthyrning',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134580947', 'label': 'Svartsö kajak', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134581015',
#   'label': 'Sandhamns guiderna',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134582041',
#   'label': 'Lidö utegym',
#   'osm_rel': '',
#   'osm_way': '1389899659'},
#  {'qid': 'Q134582361',
#   'label': 'Noret Fjärdlång grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134582626',
#   'label': 'Hamnviken utegym',
#   'osm_rel': '',
#   'osm_way': '1389909894'},
#  {'qid': 'Q134582792',
#   'label': 'Skarsand SAT grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134582833',
#   'label': 'Skarsand SAT grillplats 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134583309',
#   'label': 'Skarsand 1 grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134583669', 'label': 'Svartsö krog', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134586880', 'label': 'Svartsö Logi', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134587349',
#   'label': 'Östermarkiosken',
#   'osm_rel': '',
#   'osm_way': '833557518'},
#  {'qid': 'Q134587569',
#   'label': 'Nåttarö naturreservat',
#   'osm_rel': '1463792',
#   'osm_way': ''},
#  {'qid': 'Q134587974', 'label': 'Rånö Brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134588307', 'label': 'Låttas bageri', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134589066',
#   'label': 'Restaurang Svängen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134589221', 'label': 'Båtshaket', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134590423',
#   'label': 'Familjegrav Sundén Cullberg Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134593750',
#   'label': 'Öja tältplats',
#   'osm_rel': '',
#   'osm_way': '694128677'},
#  {'qid': 'Q134593823', 'label': 'Café Norrhamn', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134599402',
#   'label': 'Svartsö badplats',
#   'osm_rel': '',
#   'osm_way': '757247928'},
#  {'qid': 'Q134605030',
#   'label': 'Ålö Storsand dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134606657',
#   'label': 'Myruddens badplats',
#   'osm_rel': '',
#   'osm_way': '1390699454'},
#  {'qid': 'Q134606902',
#   'label': 'Södra fladen Utö, grillplats 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134606948',
#   'label': 'Södra fladens vindskydd 2, Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134607564',
#   'label': 'Rånöhamn dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134607783',
#   'label': 'Grinda tältplats dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134611499',
#   'label': 'Grillplats Arholma Nord östra',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134613388', 'label': 'Räfnäs brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134613421', 'label': 'Boda brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134613611',
#   'label': 'Sollenkroka brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134613649',
#   'label': 'Stavsnäs vinterhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134614130', 'label': 'Dalarö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134614578', 'label': 'Årsta brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134614663',
#   'label': 'Ankaruddens brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134615237',
#   'label': 'Wibomska villan',
#   'osm_rel': '',
#   'osm_way': '223271139'},
#  {'qid': 'Q134619296',
#   'label': 'Rånö gård',
#   'osm_rel': '',
#   'osm_way': '1391084662'},
#  {'qid': 'Q134619303',
#   'label': 'Hästholmsudden, Rånö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134621708',
#   'label': 'Hasselmara brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134621751',
#   'label': 'Ornöboda brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134621810',
#   'label': 'Nynäshamn brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134621885', 'label': 'Ålö brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134621955', 'label': 'Alsvik brygga', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134625421', 'label': 'SAT Ålö - Utö', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134625714',
#   'label': 'Roddbåtar att korsa mellan Finnhamn till Ingmarsö',
#   'osm_rel': '',
#   'osm_way': '39504808'},
#  {'qid': 'Q134626197',
#   'label': 'Lättinge brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134667339',
#   'label': 'Arholma dansbana',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134676671', 'label': 'Arholma Nord', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134677819',
#   'label': 'Ahlmansvikens badplats',
#   'osm_rel': '',
#   'osm_way': '605807585'},
#  {'qid': 'Q134688729',
#   'label': 'Granö badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134688746',
#   'label': 'Arholma Nord badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134688756',
#   'label': 'Granö brygga',
#   'osm_rel': '',
#   'osm_way': '605734271'},
#  {'qid': 'Q134691316',
#   'label': 'Nåttarö gård och resort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134692717',
#   'label': 'Hamnkontoret Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134692920',
#   'label': 'Nämdö Krogen, Solvik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134693218',
#   'label': 'Kyrkvikens Bar & Bistro Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134704276',
#   'label': 'Finnhamn gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134704553',
#   'label': 'Finnhamn stugbyn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134704760',
#   'label': 'Lidö vindskydd',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134705637',
#   'label': 'Ingmarsö bageri',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134705659',
#   'label': 'Ingmarsö bageribod',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134705772',
#   'label': 'Ingmarsö Gästhamn',
#   'osm_rel': '',
#   'osm_way': '1192040766'},
#  {'qid': 'Q134705878',
#   'label': 'Ingmarsö bread and breakfast',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134706371',
#   'label': 'Bistro Bryggan',
#   'osm_rel': '',
#   'osm_way': '793271425'},
#  {'qid': 'Q134710931',
#   'label': 'Grinda stugby',
#   'osm_rel': '',
#   'osm_way': '4790731'},
#  {'qid': 'Q134711795',
#   'label': 'Framfickans restaurang',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134713103', 'label': 'Grinda bageri', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134713455',
#   'label': 'Möja gästhamn kyrkviken',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134713663',
#   'label': 'Les Poissonniers',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134713953',
#   'label': 'Sandhamns bageri',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134717333',
#   'label': 'Finnhamn tältplats dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134717347',
#   'label': 'Lanthandeln dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134717362',
#   'label': 'Finnhamn stugbyn dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134720366', 'label': 'Hamn', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134721278',
#   'label': 'Lidö gästhamn Båthusviken',
#   'osm_rel': '',
#   'osm_way': '835790392'},
#  {'qid': 'Q134721309',
#   'label': 'Lidö naturhamn, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134721339',
#   'label': 'Lidö naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134721456',
#   'label': 'Lidö gård',
#   'osm_rel': '',
#   'osm_way': '455176643'},
#  {'qid': 'Q134721463',
#   'label': 'Lidö naturinformation',
#   'osm_rel': '',
#   'osm_way': '594680442'},
#  {'qid': 'Q134726978',
#   'label': 'Nämdö Skärgårdsmuseum dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134726995',
#   'label': 'Nämdö tältplats dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134727614', 'label': 'Lidö Ryssugn', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134727664',
#   'label': 'minkfarm, Lidö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134727862',
#   'label': 'Cykeluthyrning Kyrkviken Ornö',
#   'osm_rel': '',
#   'osm_way': '1393060482'},
#  {'qid': 'Q134734528',
#   'label': 'Furusunds hamnkrog',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134737023', 'label': 'Jungfruringen', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134762489',
#   'label': 'Östermarsfladen naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134776030',
#   'label': 'Landsort Norrhamn',
#   'osm_rel': '',
#   'osm_way': '290717946'},
#  {'qid': 'Q134776113',
#   'label': 'Sixtens Bodega',
#   'osm_rel': '',
#   'osm_way': '1089639083'},
#  {'qid': 'Q134776776',
#   'label': 'Nåttarö nya gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134776972',
#   'label': 'Nåttarö krog',
#   'osm_rel': '',
#   'osm_way': '186188154'},
#  {'qid': 'Q134777160',
#   'label': 'Ålö gård',
#   'osm_rel': '',
#   'osm_way': '322949097'},
#  {'qid': 'Q134777419',
#   'label': 'Nåttarö bryggkiosk',
#   'osm_rel': '',
#   'osm_way': '186188132'},
#  {'qid': 'Q134837898',
#   'label': 'Långviksgruvan',
#   'osm_rel': '',
#   'osm_way': '219838482'},
#  {'qid': 'Q134838070',
#   'label': 'Åvassa',
#   'osm_rel': '',
#   'osm_way': '4308897339'},
#  {'qid': 'Q134838210', 'label': 'Fiversättra', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q134839262',
#   'label': 'Ornö badplats, Kyrkviken',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134869532',
#   'label': 'Sandvik båtmanstorp',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134872014',
#   'label': 'Utö cykelboden',
#   'osm_rel': '',
#   'osm_way': '229110254'},
#  {'qid': 'Q134873163',
#   'label': 'Utö gästhamn',
#   'osm_rel': '',
#   'osm_way': '258778160'},
#  {'qid': 'Q134877297',
#   'label': 'Ornö elpodtaxi',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134879510',
#   'label': 'Utö Bakgård',
#   'osm_rel': '',
#   'osm_way': '5005120554'},
#  {'qid': 'Q134879651',
#   'label': 'Nämdö Hembygdsgård',
#   'osm_rel': '',
#   'osm_way': '832213164'},
#  {'qid': 'Q134881286',
#   'label': 'Hammerska ladan',
#   'osm_rel': '',
#   'osm_way': '388325539'},
#  {'qid': 'Q134889150',
#   'label': 'Norrötorpet',
#   'osm_rel': '',
#   'osm_way': '290833701'},
#  {'qid': 'Q134889482',
#   'label': 'Fjärdlång, Sjunkviken naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134889616',
#   'label': 'Fjärdlång, Mörkviken naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134889668',
#   'label': 'Fjärdlång, Rumpudden naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134889890',
#   'label': 'Fjärdlång, Vedviken naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134889928',
#   'label': 'Fjärdlång, gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134891991',
#   'label': 'Strömkajen',
#   'osm_rel': '7323914',
#   'osm_way': ''},
#  {'qid': 'Q134895185',
#   'label': 'Bryggans lilla kök',
#   'osm_rel': '',
#   'osm_way': '1395293068'},
#  {'qid': 'Q134895563',
#   'label': 'Lilla Haket & Ninas Bod',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134953620',
#   'label': 'Österhamn badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134983588',
#   'label': 'Landsorts kapells klockstapel',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134985579',
#   'label': 'Ålö brygga dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134985660',
#   'label': 'Rånö dricksvattenpump vid tältplatsen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134985757',
#   'label': 'västra hamnen dricksvatten,  Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134986918',
#   'label': 'norra hamnen dricksvatten,  Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134987098',
#   'label': 'Nåttarö nya gästhamnen dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134987117',
#   'label': 'Nåttarö nya gästhamnen dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q134987122',
#   'label': 'Nåttarö vandrarhem dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135003463',
#   'label': 'Svedtiljas restaurang',
#   'osm_rel': '',
#   'osm_way': '383557275'},
#  {'qid': 'Q135010805',
#   'label': 'Vandringsskylt SAT Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135010859',
#   'label': 'Hjärtstarare västra hamnen Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135011443',
#   'label': 'Svedtiljas restaurang cykeluthyrning',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135011579',
#   'label': 'dricksvatten tältplatsen,  Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135011988',
#   'label': 'Landsort gästhamnen, cykeluthyrning',
#   'osm_rel': '',
#   'osm_way': '1408629714'},
#  {'qid': 'Q135012404',
#   'label': 'Landsort badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135012478',
#   'label': 'Landsorts västra hamnen stugorna, hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013540',
#   'label': 'Sandhamn hjärtstartare tennisbana',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013563',
#   'label': 'Utö värdshus hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013584',
#   'label': 'Ornö bygdegård hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013590',
#   'label': 'Ornöboda hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013597',
#   'label': 'Sandhamn värdshus hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013611',
#   'label': 'Sandhamn Fläskberget hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013617',
#   'label': 'Möja brandstation hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135013701',
#   'label': 'Ramsmora Möja hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135024167',
#   'label': 'Sjöpricken',
#   'osm_rel': '',
#   'osm_way': '451870308'},
#  {'qid': 'Q135025121',
#   'label': 'Finnhamn Ragnars kiosk hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135027143',
#   'label': 'Cykel i Västerhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135027417',
#   'label': 'museet på Landsort',
#   'osm_rel': '',
#   'osm_way': '1408810518'},
#  {'qid': 'Q135034569',
#   'label': 'Finnhamns lanthandel hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135034605',
#   'label': 'STF Finnhamn vandrarhem hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135034710',
#   'label': 'Idholmens gårdsbutik hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135035871',
#   'label': 'Fjärdlång tältplats dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135041658',
#   'label': 'Kålgårdsön Trälhavets hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135041681',
#   'label': 'Gymnastiksalen Köpmanholms skola AED',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135041722',
#   'label': 'Hysängen hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135041758',
#   'label': 'Kungshamns Samfällighet Hästskovägen hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045291',
#   'label': 'Vandringsskylt SAT Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045302',
#   'label': 'Vandringsskylt SAT Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045359',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045432',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q294787', 'label': 'Öja', 'osm_rel': '6462670', 'osm_way': ''},
#  {'qid': 'Q764547',
#   'label': 'Stockholms skärgård',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q842877', 'label': 'Furusund', 'osm_rel': '', 'osm_way': '8109379'},
#  {'qid': 'Q1422492',
#   'label': 'Fjärdlångs naturreservat',
#   'osm_rel': '1463788',
#   'osm_way': ''},
#  {'qid': 'Q1480015', 'label': 'Landsort', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q1546959', 'label': 'Grinda', 'osm_rel': '2663146', 'osm_way': ''},
#  {'qid': 'Q1759193', 'label': 'Ornö', 'osm_rel': '3030279', 'osm_way': ''},
#  {'qid': 'Q1821451',
#   'label': 'Landsorts fyr',
#   'osm_rel': '',
#   'osm_way': '383557266'},
#  {'qid': 'Q2120552', 'label': 'Möja', 'osm_rel': '8346534', 'osm_way': ''},
#  {'qid': 'Q2301512',
#   'label': 'Utö naturreservat',
#   'osm_rel': '1463748',
#   'osm_way': ''},
#  {'qid': 'Q2530171',
#   'label': 'Landsorts fågelstation',
#   'osm_rel': '',
#   'osm_way': '435773966'},
#  {'qid': 'Q2837232',
#   'label': 'Sandhamn',
#   'osm_rel': '',
#   'osm_way': '64800533'},
#  {'qid': 'Q3105747', 'label': 'Runmarö', 'osm_rel': '7145257', 'osm_way': ''},
#  {'qid': 'Q3355818',
#   'label': 'Finnhamn',
#   'osm_rel': '14477930',
#   'osm_way': ''},
#  {'qid': 'Q3772710', 'label': 'Arholma', 'osm_rel': '6930812', 'osm_way': ''},
#  {'qid': 'Q5245979',
#   'label': 'Ingmarsö',
#   'osm_rel': '',
#   'osm_way': '25045412'},
#  {'qid': 'Q6976423', 'label': 'Yxlan', 'osm_rel': '', 'osm_way': '8109341'},
#  {'qid': 'Q6976731', 'label': 'Svartsö', 'osm_rel': '12893696', 'osm_way': ''},
#  {'qid': 'Q10397095',
#   'label': '15,2 cm-batteriet på Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q10417837',
#   'label': 'Arholma båk',
#   'osm_rel': '',
#   'osm_way': '292553962'},
#  {'qid': 'Q10417838',
#   'label': 'Arholma kyrka',
#   'osm_rel': '',
#   'osm_way': '292553961'},
#  {'qid': 'Q10436177', 'label': 'Brottö', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q10478848',
#   'label': 'ERSTA-batteriet på Landsort',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q10531797', 'label': 'Hässelmara', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q10552209', 'label': 'Köpmanholm', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q10553968',
#   'label': 'Landsorts kapell',
#   'osm_rel': '',
#   'osm_way': '290717945'},
#  {'qid': 'Q10561414', 'label': 'Lidö', 'osm_rel': '', 'osm_way': '4640501'},
#  {'qid': 'Q10593487',
#   'label': 'Möja Jernväg',
#   'osm_rel': '',
#   'osm_way': '227774456'},
#  {'qid': 'Q10593490',
#   'label': 'Möja kyrka',
#   'osm_rel': '',
#   'osm_way': '226055613'},
#  {'qid': 'Q10605047',
#   'label': 'Nämdö naturreservat',
#   'osm_rel': '1463777',
#   'osm_way': ''},
#  {'qid': 'Q10605049',
#   'label': 'Nämdö kyrka',
#   'osm_rel': '',
#   'osm_way': '506100183'},
#  {'qid': 'Q10605513',
#   'label': 'Nåttarö',
#   'osm_rel': '11478794',
#   'osm_way': ''},
#  {'qid': 'Q10611874',
#   'label': 'Ornö kyrka',
#   'osm_rel': '',
#   'osm_way': '220390584'},
#  {'qid': 'Q10657821',
#   'label': 'Runmarö kapell',
#   'osm_rel': '',
#   'osm_way': '241040806'},
#  {'qid': 'Q10658747', 'label': 'Rånö', 'osm_rel': '11678328', 'osm_way': ''},
#  {'qid': 'Q10661170',
#   'label': 'Sandhamns kapell',
#   'osm_rel': '',
#   'osm_way': '265058982'},
#  {'qid': 'Q10683742',
#   'label': 'Sundby herrgård',
#   'osm_rel': '',
#   'osm_way': '227528964'},
#  {'qid': 'Q10711619', 'label': 'Utö gruvor', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q10711621',
#   'label': 'Utö kyrka',
#   'osm_rel': '',
#   'osm_way': '237190146'},
#  {'qid': 'Q10711622',
#   'label': 'Utö skjutfält',
#   'osm_rel': '10694833',
#   'osm_way': ''},
#  {'qid': 'Q10726505', 'label': 'Ålö', 'osm_rel': '10694823', 'osm_way': ''},
#  {'qid': 'Q10727792',
#   'label': 'Östanviks gård',
#   'osm_rel': '',
#   'osm_way': '270877107'},
#  {'qid': 'Q15695240',
#   'label': 'Bygdemuseet Ornö sockenstuga',
#   'osm_rel': '',
#   'osm_way': '227701074'},
#  {'qid': 'Q17634097',
#   'label': 'Silverträsket',
#   'osm_rel': '',
#   'osm_way': '39050054'},
#  {'qid': 'Q17634106',
#   'label': 'Styrsvikträsket',
#   'osm_rel': '',
#   'osm_way': '39050048'},
#  {'qid': 'Q18290939', 'label': 'Ingmarsö', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q18291743',
#   'label': 'Lidö värdshus',
#   'osm_rel': '',
#   'osm_way': '455176637'},
#  {'qid': 'Q18292099', 'label': 'Långvik', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q26253472', 'label': 'Ramsmora', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q28375391', 'label': 'Yxlans fyr', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q28934440',
#   'label': 'Björkö-Arholma sjömannaförening',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q28934474',
#   'label': 'Sandhamns museum',
#   'osm_rel': '',
#   'osm_way': '329728793'},
#  {'qid': 'Q29528279',
#   'label': 'Pestkyrkogård, Öja-Landsort',
#   'osm_rel': '',
#   'osm_way': '698715293'},
#  {'qid': 'Q30158128',
#   'label': 'Lidö naturreservat',
#   'osm_rel': '1463761',
#   'osm_way': ''},
#  {'qid': 'Q30161368',
#   'label': 'Finnhamns naturreservat',
#   'osm_rel': '1463800',
#   'osm_way': ''},
#  {'qid': 'Q30162906',
#   'label': 'Kålgårdsöns naturreservat',
#   'osm_rel': '10626459',
#   'osm_way': ''},
#  {'qid': 'Q30164971',
#   'label': 'Ålö-Rånö naturreservat',
#   'osm_rel': '1463767',
#   'osm_way': ''},
#  {'qid': 'Q30165452',
#   'label': 'Arholma-Idö naturreservat',
#   'osm_rel': '1463750',
#   'osm_way': ''},
#  {'qid': 'Q30167695',
#   'label': 'Grinda naturreservat',
#   'osm_rel': '1463789',
#   'osm_way': ''},
#  {'qid': 'Q30242782', 'label': 'Berg', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q30315439',
#   'label': 'Sandhamns tullhus',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q31891076', 'label': 'Österhamn', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q31892331', 'label': 'Kolsvik', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q31895480', 'label': 'Edesnäs', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q32247988', 'label': 'Halsudden', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q32278807',
#   'label': 'Lilla Jolpan',
#   'osm_rel': '',
#   'osm_way': '696330987'},
#  {'qid': 'Q32301589', 'label': 'Nåttaröhals', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q32904803',
#   'label': 'Batteri Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q33108739', 'label': 'Ornö', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q33108886', 'label': 'Yxlö', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q33180827',
#   'label': 'Sandhamns lotsstation',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q46946584', 'label': 'Sandön', 'osm_rel': '', 'osm_way': '24811650'},
#  {'qid': 'Q48890062', 'label': 'Nämdö', 'osm_rel': '4173351', 'osm_way': ''},
#  {'qid': 'Q56301720',
#   'label': 'Furusunds kvarn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q56780332',
#   'label': 'Fjärdlång',
#   'osm_rel': '',
#   'osm_way': '24846389'},
#  {'qid': 'Q56804997', 'label': 'Utö', 'osm_rel': '6315443', 'osm_way': ''},
#  {'qid': 'Q63345339',
#   'label': 'Drottninggrottan',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q63432491',
#   'label': 'Konstnären Axel Sjöberg 1866–1950',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q63615597',
#   'label': 'Strindbergsgården',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q81263800',
#   'label': 'Batteri Sandö-Oxudde',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q89197643', 'label': 'Ornö skola', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q106575390', 'label': 'Möja Bio', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q106653497',
#   'label': 'Sandhamn, Fläskberget',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q106653509',
#   'label': 'Stora Trouvillestranden',
#   'osm_rel': '',
#   'osm_way': '64790110'},
#  {'qid': 'Q106653538',
#   'label': 'Östervikens badplats',
#   'osm_rel': '',
#   'osm_way': '941508110'},
#  {'qid': 'Q106678630',
#   'label': 'Jerkers uddes badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q106680381',
#   'label': 'Ålö Storsand',
#   'osm_rel': '10694817',
#   'osm_way': ''},
#  {'qid': 'Q107290890',
#   'label': 'Ornöboda badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q108067637',
#   'label': 'Gruvbyns utegym',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q108159298',
#   'label': 'Öja-Landsort Naturvårdsområde',
#   'osm_rel': '',
#   'osm_way': '103228585'},
#  {'qid': 'Q111335301',
#   'label': 'Runmarö skola',
#   'osm_rel': '',
#   'osm_way': '224352888'},
#  {'qid': 'Q111335438',
#   'label': 'Svartsö skola',
#   'osm_rel': '',
#   'osm_way': '958700831'},
#  {'qid': 'Q111335439',
#   'label': 'Möja skola',
#   'osm_rel': '',
#   'osm_way': '226043383'},
#  {'qid': 'Q113481847',
#   'label': 'Finnhamn, utegym',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q114039794',
#   'label': 'Storsand, Nåttarö',
#   'osm_rel': '',
#   'osm_way': '322935629'},
#  {'qid': 'Q114574693',
#   'label': 'Vandringsled Ålö runt',
#   'osm_rel': '9775802',
#   'osm_way': ''},
#  {'qid': 'Q115094918',
#   'label': 'Långvik yttre badplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q115303225',
#   'label': 'Möja kyrkogård',
#   'osm_rel': '8720932',
#   'osm_way': ''},
#  {'qid': 'Q115303226',
#   'label': 'Nämndö kyrkogård',
#   'osm_rel': '',
#   'osm_way': '506100197'},
#  {'qid': 'Q135045488',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045682',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135045892',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135046168',
#   'label': 'Vandringsskylt SAT Nåttarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135046665',
#   'label': 'Vandringsskylt SAT Rånö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135048381',
#   'label': 'Vandringsskylt SAT Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135048658',
#   'label': 'Vandringsskylt SAT Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135048975',
#   'label': 'Vandringsskylt SAT Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135048990',
#   'label': 'Vandringsskylt SAT Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135048998',
#   'label': 'Vandringsskylt SAT Ålö Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135049010',
#   'label': 'Vandringsskylt SAT Utö Ålö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135050059',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135050889',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135051272',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135052427',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135052516',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135052708',
#   'label': 'Vandringsskylt SAT Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135053596',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135054141',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135054293',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135054522',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135055618',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135056610',
#   'label': 'Vandringsskylt SAT Runmarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135057039',
#   'label': 'Vandringsskylt SAT Runmarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135057413',
#   'label': 'Vandringsskylt SAT Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135057751',
#   'label': 'Vandringsskylt SAT Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135057972',
#   'label': 'Vandringsskylt SAT Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135060190',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135060467',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135060651',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135060878',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135061041',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135061205',
#   'label': 'Vandringsskylt SAT Svartsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135062583',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135062808',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135063085',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135063320',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135063491',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135063516',
#   'label': 'Vandringsskylt SAT Finnhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135064407',
#   'label': 'Vandringsskylt SAT Finnhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135064468',
#   'label': 'Vandringsskylt SAT Finnhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135064544',
#   'label': 'Vandringsskylt SAT Lidö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135065022',
#   'label': 'Vandringsskylt SAT Lidö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135065340',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135085367',
#   'label': 'Rånö stugbyn dricksvattenpump',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135086439',
#   'label': 'Vandringsskylt SAT Nämdö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135086883',
#   'label': 'Vandringsskylt SAT Nämdö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135087121',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135087297',
#   'label': 'Vandringsskylt SAT Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135087816', 'label': 'Runmarö rum', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q135091732',
#   'label': 'Christiansborg',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135102475',
#   'label': 'Hotell Dagmar',
#   'osm_rel': '',
#   'osm_way': '388325610'},
#  {'qid': 'Q135103433',
#   'label': 'Ornö badplats Kyrkviken',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135105075',
#   'label': 'Hembygdsgård Svartsö',
#   'osm_rel': '',
#   'osm_way': '958701083'},
#  {'qid': 'Q135107155',
#   'label': 'Svartsö gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135107242',
#   'label': 'Svartsö Lanthandel  cykeluthyrning',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135107443',
#   'label': 'Svartsö Sjöbodar',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135107753',
#   'label': 'Svartsö bryggcafe',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135108621',
#   'label': 'Grinda lantbruk',
#   'osm_rel': '',
#   'osm_way': '427182331'},
#  {'qid': 'Q135109946',
#   'label': 'Arholma Bryggcafé',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135109946',
#   'label': 'Arholma Bryggcafé',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135110019',
#   'label': 'Vandrarhem Bull-August gård',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135110110', 'label': 'Möja bageri', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q135110316', 'label': 'Möja hamnbar', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q135111506',
#   'label': 'Hamnmagasinet',
#   'osm_rel': '',
#   'osm_way': '229110249'},
#  {'qid': 'Q135114682',
#   'label': 'Utö värdshus cykeluthyrning',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135117359',
#   'label': 'Cykeluthyrning Tempo Runmarö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135152513',
#   'label': 'Sundby Gård – Magasinets café',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135152596',
#   'label': 'Sundby Gård gårdsbutik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135152644',
#   'label': 'Gittans-KBB på Ornö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135152816',
#   'label': 'Ornö Museums trädgårdscafé',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153043',
#   'label': 'Ornö båtvarv självservering',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153107',
#   'label': 'Ornö byggdegård',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153157',
#   'label': 'Björkösunds Fisk',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153213',
#   'label': 'Östra Hässelmara Gård',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153270',
#   'label': 'Gästbryggan vid Ornö macken',
#   'osm_rel': '',
#   'osm_way': '295918078'},
#  {'qid': 'Q135153326',
#   'label': 'Gästbryggan vid Ornö Båtvarv, Brunnsviken',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135153361',
#   'label': 'Cykeluthyrning vid Ornö båtvarv',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135197036',
#   'label': 'Finnhamn stugbyn dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135197156',
#   'label': 'Finnhamn stugbyn dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135217025',
#   'label': 'Villa Söderängen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135218755',
#   'label': 'Bastu på Nämdö',
#   'osm_rel': '',
#   'osm_way': '504184973'},
#  {'qid': 'Q135226164',
#   'label': 'Dykarbaren Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135226435',
#   'label': 'Västerudd, Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135226572',
#   'label': 'Västeruddens badplats',
#   'osm_rel': '',
#   'osm_way': '589299279'},
#  {'qid': 'Q135230746',
#   'label': 'Skutviken Rånö dricksvattenpump',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135266166',
#   'label': 'Fältspatsgruva',
#   'osm_rel': '',
#   'osm_way': '1413799336'},
#  {'qid': 'Q135267113',
#   'label': 'Kinnekulle badplats, Ålö',
#   'osm_rel': '',
#   'osm_way': '1203469960'},
#  {'qid': 'Q135267120',
#   'label': 'Östra Ålö grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135267910',
#   'label': 'Cykeluthyrning Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135267999',
#   'label': 'Arholma camping dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135268016',
#   'label': 'Arholma Österhamn dricksvatten',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135268035', 'label': 'Arholma sauna', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q135336466',
#   'label': 'Finnhamn gästhamn grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135399764',
#   'label': 'Sliphuset Finnhamn',
#   'osm_rel': '',
#   'osm_way': '222762708'},
#  {'qid': 'Q135400127',
#   'label': 'Rånöhamn naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135400223',
#   'label': 'Skutvikens naturhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135406877',
#   'label': 'Norrtälje brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135414637',
#   'label': 'Restaurang Oasen',
#   'osm_rel': '',
#   'osm_way': '455176644'},
#  {'qid': 'Q135415254',
#   'label': 'Lidö bastu',
#   'osm_rel': '',
#   'osm_way': '1415844039'},
#  {'qid': 'Q135415303',
#   'label': 'Västergårdens boende, Lidö',
#   'osm_rel': '',
#   'osm_way': '507890626'},
#  {'qid': 'Q135416156',
#   'label': 'bastu norra Svartsö ångbåtsbrygga.',
#   'osm_rel': '',
#   'osm_way': '432942493'},
#  {'qid': 'Q135423048',
#   'label': 'dricksvatten Östanviks gård',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135423081',
#   'label': 'Östanviks gårdsbutik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135423626',
#   'label': 'Solberga gårdsbutik',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135428249', 'label': 'Cafe Ankaret', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q135428282',
#   'label': 'Sandhamn Missionshuset Bed & Breakfast',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135431929',
#   'label': 'Missionshus Sandhamn',
#   'osm_rel': '',
#   'osm_way': '701914920'},
#  {'qid': 'Q135434981',
#   'label': 'dricksvatten Bergs hamn Möja',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135437122',
#   'label': 'Restaurang Strandbaren Idöborg',
#   'osm_rel': '',
#   'osm_way': '224465745'},
#  {'qid': 'Q135437146',
#   'label': 'Idöborg gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135437170',
#   'label': 'Stora Kalholmen brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135437255',
#   'label': 'Idöborg brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135442525',
#   'label': 'Ingmarsö gårdsbutik och gårdsmejeri',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135443007',
#   'label': 'Brunströms bod i Berg',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135443020',
#   'label': 'Möja Hembygdsmuseum',
#   'osm_rel': '',
#   'osm_way': '231008287'},
#  {'qid': 'Q135443083',
#   'label': 'Bastu Ostholmen på Möja',
#   'osm_rel': '',
#   'osm_way': '231871543'},
#  {'qid': 'Q135443360',
#   'label': 'Ramsmora badklippor',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135443569',
#   'label': 'dricksvatten Lidö gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135458780',
#   'label': 'Dricksvatten vid Rånö livs',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135466276',
#   'label': 'Trollgården Restaurang',
#   'osm_rel': '',
#   'osm_way': '224352923'},
#  {'qid': 'Q135475767',
#   'label': 'Sands Hotell',
#   'osm_rel': '',
#   'osm_way': '329728726'},
#  {'qid': 'Q135843470',
#   'label': 'Arholma Nord brygga',
#   'osm_rel': '',
#   'osm_way': '1422638676'},
#  {'qid': 'Q135874534',
#   'label': 'Vandrarhemsvikens gästhamn, Finnhamn',
#   'osm_rel': '',
#   'osm_way': '1422807518'},
#  {'qid': 'Q135883737',
#   'label': 'Grillplats Nordvästra Nåttarö vid Naturhamnen',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135890833',
#   'label': 'Långvik Coop',
#   'osm_rel': '',
#   'osm_way': '226745409'},
#  {'qid': 'Q135898761',
#   'label': 'Arholma gästbrygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900081',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900175',
#   'label': 'Nåttarö hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900415',
#   'label': 'Ahlmansvikens gästhamn',
#   'osm_rel': '',
#   'osm_way': '471412287'},
#  {'qid': 'Q135900531',
#   'label': 'Arholma handel hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900574',
#   'label': 'Roslagens östra pastorat hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900640',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135900661',
#   'label': 'Arholma Intresseförening Ensfyrens väg hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135901032',
#   'label': 'Österhamn 4990875347 Hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135901115',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135905118',
#   'label': 'Södra Sandvik Utö grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135905224',
#   'label': 'Kroka By dricksvattenpump',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135916989',
#   'label': 'Vandringsskylt SAT Möja',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135917088',
#   'label': 'Vandringsskylt SAT Finnhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135917318',
#   'label': 'Ragnars kiosk kajaker',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135969641',
#   'label': 'Grinda värdshus hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135969918',
#   'label': 'Grillplats 2 vid badstrand, Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135971987',
#   'label': 'Grillplats Grinda stugbyn 3',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135972088',
#   'label': 'Grillplats Grinda stugbyn 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135972925',
#   'label': 'Källvikens bastu',
#   'osm_rel': '',
#   'osm_way': '1392291391'},
#  {'qid': 'Q135972992',
#   'label': 'Grinda Gästhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135973416',
#   'label': 'Lillsved brygga',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q135973655',
#   'label': 'Vandringsskylt SAT Grinda',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136036748',
#   'label': 'Grillplats Grinda stugbyn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136087206',
#   'label': 'Bistro bryggan, grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136164699',
#   'label': 'Utö Grillkiosk',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136193620',
#   'label': 'Finnhamns bastu',
#   'osm_rel': '',
#   'osm_way': '1305192609'},
#  {'qid': 'Q136198240',
#   'label': 'Nåttarö bastu vid stugbyn',
#   'osm_rel': '',
#   'osm_way': '833560682'},
#  {'qid': 'Q136202829',
#   'label': 'Svartsö skärgårdshotell och vandrarhem Hjärtstartare',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136207068',
#   'label': 'Bastuflotte Sandhamn',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136207103',
#   'label': 'Sandhamns hotell, bastu',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136214806',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136214817',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136214840',
#   'label': 'Vandringsskylt SAT Arholma',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136298469',
#   'label': 'Grinda grillplats Klubbudden 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136337568',
#   'label': 'Saltvik grillplats, Möja',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136337707',
#   'label': 'Möja Turistförening',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136342609', 'label': 'Pentaboden', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q136342734',
#   'label': 'Grinda Sea Lodge bastu',
#   'osm_rel': '',
#   'osm_way': '227166923'},
#  {'qid': 'Q136349659',
#   'label': 'Vandringsskylt SAT Rånö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136356030',
#   'label': 'Vandringsskylt SAT Möja',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136363283',
#   'label': 'Södra Storsand Ålö grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136374336',
#   'label': 'Skarsand norra grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136374419',
#   'label': 'Skarsand enkel grillplats',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136374558',
#   'label': 'Skarsand norra 2',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136390034',
#   'label': 'Vandringsskylt SAT Rånö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136390863',
#   'label': 'Vandringsskylt SAT Rånö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136391100',
#   'label': 'Vandringsskylt SAT Ingmarsö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136433169', 'label': 'Seglarbaren', 'osm_rel': '', 'osm_way': ''},
#  {'qid': 'Q136437056',
#   'label': 'Affärshuset, Utö',
#   'osm_rel': '',
#   'osm_way': ''},
#  {'qid': 'Q136437789',
#   'label': 'Fyrvaktarbostad',
#   'osm_rel': '',
#   'osm_way': '383557268'},
#  {'qid': 'Q136438341',
#   'label': 'Fyrmästarbostad',
#   'osm_rel': '',
#   'osm_way': '383557299'}]
