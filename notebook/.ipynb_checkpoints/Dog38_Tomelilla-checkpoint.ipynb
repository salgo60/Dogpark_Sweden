# %% [markdown]
# ### Tomelilla kommun
# * [Issue #38](https://github.com/salgo60/Dogpark_Sweden/issues/38)
# * Denna [Notebook Dog38_Tomelilla.ipynb](https://github.com/salgo60/Dogpark_Sweden/blob/main/notebook/Dog38_Tomelilla.ipynb)
# * karta [Tomelilla_dog_38.html](https://raw.githack.com/salgo60/Dogpark_Sweden/main/notebook/Tomelilla_dog_38.html)

# %%
import requests
import json
import binascii
import folium
import geopandas as gpd
import pandas as pd
from shapely import wkb

# 1. Hämta JSON-data från Tomelilla
url = "https://data.tomelilla.se/rowstore/dataset/1275d7eb-efdf-4892-a864-4f3a40d72594/json"
data = requests.get(url).json()["results"]

# 2. Skapa DataFrame
df = pd.DataFrame(data)

# 3. Konvertera WKB-hex till Shapely-geometri
df["geometry"] = df["geom"].apply(lambda x: wkb.loads(binascii.unhexlify(x)) if x else None)

# 4. Gör till GeoDataFrame i SWEREF 99 TM (EPSG:3006)
gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:3006")

# 5. Konvertera till WGS84 (EPSG:4326) för Folium
gdf = gdf.to_crs(epsg=4326)

# 🧩 Extrahera punkter ur MultiPoint (tar första punkten)
gdf["point"] = gdf["geometry"].apply(
    lambda g: list(g.geoms)[0] if g.geom_type == "MultiPoint" else g
)

# 6. Skapa Folium-karta centrerad på Tomelilla
center = [gdf["point"].y.mean(), gdf["point"].x.mean()]
m = folium.Map(location=center, zoom_start=13, tiles="OpenStreetMap")

# 7. Lägg till punkter
for _, row in gdf.iterrows():
    p = row["point"]
    popup_text = (
        f"<b>Hundlatrinpåse</b><br>"
        f"<b>ID:</b> {row['﻿skotselobj_id']}<br>"
        f"<b>Utförare:</b> {row['utforare'] or '-'}<br>"
        f"<b>Datum:</b> {row['inskrivet']}"
    )
    folium.Marker(
        location=[p.y, p.x],
        popup=popup_text,
        icon=folium.Icon(color="green", icon="paw", prefix="fa")
    ).add_to(m)

# 8. Spara till HTML
m.save("Tomelilla_dog_38.html")

print("✅ Kartan Tomelilla_dog_38.html har skapats!")
# Out:
# ✅ Kartan Tomelilla_dog_38.html har skapats!

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d511b109234a815fa19edd90db5eada4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d511b109234a815fa19edd90db5eada4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d511b109234a815fa19edd90db5eada4 = L.map(
#                 &quot;map_d511b109234a815fa19edd90db5eada4&quot;,
#                 {
#                     center: [55.458937734075846, 9.913490815367844],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbf1e196116312da8c877bdbcdfb7f32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbf1e196116312da8c877bdbcdfb7f32.addTo(map_d511b109234a815fa19edd90db5eada4);
#
#
#             var marker_1d509e0fc506ee6e10ad7ef08f30bbc4 = L.marker(
#                 [55.45946417062785, 9.919974814937317],
#                 {
# }
#             ).addTo(map_d511b109234a815fa19edd90db5eada4);
#
#
#             var icon_67bafc995b4b7e0b9d0151474d2b5617 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;paw&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4bc1b316947fa83b2d268260218ff683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_292d8fb9472d397bc91844d2eed80b59 = $(`&lt;div id=&quot;html_292d8fb9472d397bc91844d2eed80b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hundlatrinpåse&lt;/b&gt;&lt;br&gt;&lt;b&gt;ID:&lt;/b&gt; 200080&lt;br&gt;&lt;b&gt;Utförare:&lt;/b&gt; GK&lt;br&gt;&lt;b&gt;Datum:&lt;/b&gt; 09/06/2018 00:00:00&lt;/div&gt;`)[0];
#                 popup_4bc1b316947fa83b2d268260218ff683.setContent(html_292d8fb9472d397bc91844d2eed80b59);
#
#
#
#         marker_1d509e0fc506ee6e10ad7ef08f30bbc4.bindPopup(popup_4bc1b316947fa83b2d268260218ff683)
#         ;
#
#
#
#
#                 marker_1d509e0fc506ee6e10ad7ef08f30bbc4.setIcon(icon_67bafc995b4b7e0b9d0151474d2b5617);
#
#
#             var marker_827420d3238a86786444876d00679544 = L.marker(
#                 [55.45888163638723, 9.914657667606946],
#                 {
# }
#             ).addTo(map_d511b109234a815fa19edd90db5eada4);
#
#
#             var icon_251f3782154daa20f360a37aad696ff8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;paw&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_19b7c9e17304c938917973ba12df5a81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f10db9f70af46a121fef587e56293e9b = $(`&lt;div id=&quot;html_f10db9f70af46a121fef587e56293e9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hundlatrinpåse&lt;/b&gt;&lt;br&gt;&lt;b&gt;ID:&lt;/b&gt; 200136&lt;br&gt;&lt;b&gt;Utförare:&lt;/b&gt; GK&lt;br&gt;&lt;b&gt;Datum:&lt;/b&gt; 09/06/2018 00:00:00&lt;/div&gt;`)[0];
#                 popup_19b7c9e17304c938917973ba12df5a81.setContent(html_f10db9f70af46a121fef587e56293e9b);
#
#
#
#         marker_827420d3238a86786444876d00679544.bindPopup(popup_19b7c9e17304c938917973ba12df5a81)
#         ;
#
#
#
#
#                 marker_827420d3238a86786444876d00679544.setIcon(icon_251f3782154daa20f360a37aad696ff8);
#
#
#             var marker_9aba6584cd1e78929e94555effb03404 = L.marker(
#                 [55.46055962572483, 9.908369453338036],
#                 {
# }
#             ).addTo(map_d511b109234a815fa19edd90db5eada4);
#
#
#             var icon_19dc5f5499c463c6a3184b2e83da2ae0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;paw&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c23f94855cd90d4456d092ae59409835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_521a097e8cf33396c7caf0263960e9ec = $(`&lt;div id=&quot;html_521a097e8cf33396c7caf0263960e9ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hundlatrinpåse&lt;/b&gt;&lt;br&gt;&lt;b&gt;ID:&lt;/b&gt; 200101&lt;br&gt;&lt;b&gt;Utförare:&lt;/b&gt; GK&lt
